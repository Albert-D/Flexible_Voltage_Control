# %%
import torch
import sys
from loguru import logger
from config import Config

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt

import random
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %%
class MainPolicyNet(nn.Module):
    def __init__(self, env, obs_dim, action_dim, hidden_dim, scale=1.0, init_w=3e-3):
        super(MainPolicyNet, self).__init__()

        self.env = env
        self.hidden_dim = hidden_dim
        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.scale = scale

        # this matrix used to guarantee the sum of w matrix is postive
        self.w_triangle = torch.ones((self.hidden_dim, self.hidden_dim))
        self.w_triangle = -torch.triu(self.w_triangle, diagonal=0) + torch.triu(self.w_triangle, diagonal=2)\
                        + 2*torch.eye(self.hidden_dim)

        # this matrix used to guarantee b_i >= b_{i-1}
        self.b_triangle = torch.ones((self.hidden_dim, self.hidden_dim))
        self.b_triangle = torch.triu(self.b_triangle, diagonal=1)

        #define parameters of NN
        self.b = torch.nn.Parameter(torch.rand(self.hidden_dim), requires_grad=True)
        self.c = torch.nn.Parameter(torch.rand(self.hidden_dim), requires_grad=True)
        self.q = torch.nn.Parameter(torch.rand(action_dim, self.hidden_dim), requires_grad=True)
        self.z = torch.nn.Parameter(torch.rand(action_dim, self.hidden_dim), requires_grad=True)

        self.b.data = (self.b.data / torch.sum(self.b.data)) * self.scale
        self.c.data = (self.c.data / torch.sum(self.c.data)) * self.scale

    def forward(self, state):
        # input = torch.cat((state,topology), dim=1)
        input = state
        input_dim = input.size(dim=1)

        # self.q = self.q + Config.K   # ensure \sum{w_plus} \geq 0
        with torch.no_grad():
            q_constrain = 0.1 + 5.0 * torch.sigmoid(self.q)
            z_constrain = 0.1 + 5.0 * torch.sigmoid(self.z)

            # self.b.data = self.b.data.clamp(min=0)
            # self.c.data = self.c.data.clamp(min=0)
            self.b.data = self.b.data.clamp(min=0) / torch.norm(self.b.data, 1) * self.scale
            self.c.data = self.c.data.clamp(min=0) / torch.norm(self.c.data, 1) * self.scale

        # self.w_plus = torch.square(self.q) @ self.w_triangle
        # self.w_minus = -torch.square(self.z) @ self.w_triangle
        self.w_plus = q_constrain @ self.w_triangle
        self.w_minus = -z_constrain @ self.w_triangle

        self.b_plus=torch.matmul(-self.b, self.b_triangle) - torch.tensor(self.env.vmax - 0.005)
        self.b_minus=torch.matmul(-self.c, self.b_triangle) + torch.tensor(self.env.vmin + 0.005)
        # self.b_plus=torch.matmul(-self.b, self.b_triangle) - torch.tensor(self.env.vmax)
        # self.b_minus=torch.matmul(-self.b, self.b_triangle) + torch.tensor(self.env.vmin)

        self.nonlinear_plus = F.relu(input.unsqueeze(2) + self.b_plus.unsqueeze(1)) @ self.w_plus.transpose(1,2)
        self.nonlinear_minus = F.relu(-input.unsqueeze(2) + self.b_minus.unsqueeze(1)) @ self.w_minus.transpose(1,2)
        
        y = self.nonlinear_plus + self.nonlinear_minus

        return y.squeeze(-1)
    

class HyperXnet(nn.Module):
    def __init__(self, topology_dim, x_hidden_dim, hidden_dim, action_dim):
        super(HyperXnet,self).__init__()
        self.hidden_dim = hidden_dim
        self.action_dim = action_dim
        self.linear1 = nn.Linear(topology_dim, x_hidden_dim)
        self.linear2 = nn.Linear(x_hidden_dim, x_hidden_dim)
        self.linear3 = nn.Linear(x_hidden_dim, hidden_dim * 2 + action_dim * hidden_dim * 2)

    def forward(self, topology):
        
        topology.requires_grad = True

        # x = nn.BatchNorm2d(topology)
        x = torch.relu(self.linear1(topology))
        x = torch.relu(self.linear2(x))
        x = self.linear3(x)

        # Split the output into the respective sizes
        b = x[:, :self.hidden_dim]
        c = x[:, self.hidden_dim:2*self.hidden_dim]
        q = x[:, 2*self.hidden_dim:2*self.hidden_dim + self.action_dim*self.hidden_dim]
        z = x[:, 2*self.hidden_dim + self.action_dim*self.hidden_dim:]
        
        # Reshape q and z to match the required dimensions
        q = q.reshape(-1, self.action_dim, self.hidden_dim)
        z = z.reshape(-1, self.action_dim, self.hidden_dim)
        
        return b, c, q, z
    

class HyperFlexibleNet(nn.Module):
    def __init__(self, env, obs_dim, topology_dim, x_hidden_dim, hidden_dim, action_dim, scale=1.0, init_w=3e-3):
        super(HyperFlexibleNet,self).__init__()
        self.hyper_x_net = HyperXnet(topology_dim, x_hidden_dim, hidden_dim, action_dim)
        self.policy_net = MainPolicyNet(env, obs_dim, action_dim, hidden_dim, scale, init_w)

    def forward(self, state, topolgy):
        b, c, q, z = self.hyper_x_net(topolgy)

        # Set the parameters of policy_net dynamically
        self.policy_net.b = nn.Parameter(b, requires_grad=True)

        self.policy_net.c = nn.Parameter(c, requires_grad=True)
        self.policy_net.q = nn.Parameter(q, requires_grad=True)
        self.policy_net.z = nn.Parameter(z, requires_grad=True)

        y = self.policy_net(state)

        return y
    
def plot_net(net, topology):
    fig, ax = plt.subplots()
    
    s_array = np.arange(0.8,1.21,0.01)
    a_array_baseline = -(np.maximum(s_array-1.05, 0)-np.maximum(0.95-s_array, 0))

    state = torch.cuda.FloatTensor(s_array).unsqueeze(0)

    a_array = -net(state, topology).squeeze(0).detach().cpu().numpy()
    
    ax.plot(s_array, a_array_baseline, label = 'Baseline')
    ax.plot(s_array, a_array, label = 'RL')
    plt.show()

# %%
logger.info(f"Using {device} device")

from Environment import *

injection_bus = np.array([9, 10, 15, 19, 32, 35, 47, 58, 65, 74, 82, 91, 103, 60]) #11, 36, 75,/ 1,5,9
pp_net = create_123bus()
test_env = Env_123bus(pp_net, injection_bus)
state, topology, senario = test_env.reset_topo()

topology = torch.cuda.FloatTensor(topology).unsqueeze(0)
# topology = topology.expand(64,113)
logger.info(topology.shape)

test_hypernet = HyperXnet(113, 1024, 512, 1)
b,c,q,z = test_hypernet(topology)
print(b.shape,c.shape,q.shape,z.shape)

# state = torch.cuda.FloatTensor(state[0].reshape(1,)).unsqueeze(0)
# # state = state.expand(64,1)
# logger.info(state.shape)

test_net = HyperFlexibleNet(test_env, test_env.obs_dim, 113, 1024, 256, test_env.action_dim)

# test_net(state, topology)

plot_net(test_net,topology)
# Out:
# 2024-04-23 16:34:49.568 | INFO     | __main__:<module>:1 - Using cuda device
# 2024-04-23 16:34:49.900 | INFO     | __main__:<module>:12 - torch.Size([1, 113])
# torch.Size([1, 512]) torch.Size([1, 512]) torch.Size([1, 1, 512]) torch.Size([1, 1, 512])

# %%
w_triangle = torch.ones((512, 512))
w_triangle = -torch.triu(w_triangle, diagonal=0) + torch.triu(w_triangle, diagonal=2)\
                + 2*torch.eye(512)

# this matrix used to guarantee b_i >= b_{i-1}
b_triangle = torch.ones((512, 512))
b_triangle = torch.triu(b_triangle, diagonal=1)

# %%
b_plus = b @ b_triangle
print(b_plus.shape)

b_ = state.unsqueeze(2) @ torch.ones(1,512) + b_plus.unsqueeze(1)
b_1 = state.unsqueeze(2) + b_plus.unsqueeze(1)
print(b_1.shape)

w_plus= z @ w_triangle
w_plus.transpose(1,2).shape

y = b_ @ w_plus.transpose(1,2)
y = y.squeeze(-1)
y.shape
# Out:
# torch.Size([64, 512])
# torch.Size([64, 1, 512])
# torch.Size([64, 1])

# %%
s_array = np.arange(0.8,1.21,0.01)
state = torch.arange(0.8, 1.21, 0.01)
state = torch.cuda.FloatTensor(state).unsqueeze(0)
print(state,state.shape)

action_baseline = (np.maximum(s_array-1.05, 0)-np.maximum(0.95-s_array, 0))
print(action_baseline)

# topology = torch.cuda.FloatTensor(topology).squeeze(0)
# topology = topology.expand(64,113)
# logger.info(topology.shape)

# test_net = HyperFlexibleNet(test_env, test_env.obs_dim, 113, 1024, 256, test_env.action_dim)

# test_net(state, topology)
# Out:
# tensor([[0.8000, 0.8100, 0.8200, 0.8300, 0.8400, 0.8500, 0.8600, 0.8700, 0.8800,
#          0.8900, 0.9000, 0.9100, 0.9200, 0.9300, 0.9400, 0.9500, 0.9600, 0.9700,
#          0.9800, 0.9900, 1.0000, 1.0100, 1.0200, 1.0300, 1.0400, 1.0500, 1.0600,
#          1.0700, 1.0800, 1.0900, 1.1000, 1.1100, 1.1200, 1.1300, 1.1400, 1.1500,
#          1.1600, 1.1700, 1.1800, 1.1900, 1.2000]], device='cuda:0') torch.Size([1, 41])
# [-1.50000000e-01 -1.40000000e-01 -1.30000000e-01 -1.20000000e-01
#  -1.10000000e-01 -1.00000000e-01 -9.00000000e-02 -8.00000000e-02
#  -7.00000000e-02 -6.00000000e-02 -5.00000000e-02 -4.00000000e-02
#  -3.00000000e-02 -2.00000000e-02 -1.00000000e-02  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  2.22044605e-16  1.00000000e-02  2.00000000e-02
#   3.00000000e-02  4.00000000e-02  5.00000000e-02  6.00000000e-02
#   7.00000000e-02  8.00000000e-02  9.00000000e-02  1.00000000e-01
#   1.10000000e-01  1.20000000e-01  1.30000000e-01  1.40000000e-01
#   1.50000000e-01]
